# %% [markdown]
# #Nhiệm vụ build 1 mô hình dự đoán loài chim qua ảnh, có tổng cộng 525 loài. Mỗi ảnh chỉ chưa 1 loài chim duy nhất. Sử dụng pre-trained (EfficientNet_B0)

# %%
# !unzip -q "/content/drive/MyDrive/uploads/ai-4-e-dl-5-coursework-1.zip" -d /content/dataset
# Out:
# A

# %%
# !ls "/content/dataset"
# Out:
# sample_submission.csv  test  test.csv  train  train.csv

# %%
# !ls "/content/dataset/test"
# Out:
# test_folder

# %%
# !ls "/content/dataset/train"
# Out:
# train

# %%
# !ls "/content/dataset"
# Out:
# sample_submission.csv  test  test.csv  train  train.csv

# %%
#import libraries
import os
from PIL import Image
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models
from matplotlib import pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
#exploring data
train_df = pd.read_csv("/content/dataset/train.csv")
print(f"train_df shape: {train_df.shape}")
print(train_df.columns)
display(train_df.head())

test_df = pd.read_csv("/content/dataset/test.csv")
print(f"test_df shape: {test_df.shape}")
print(test_df.columns)
display(test_df.head())
# Out:
# train_df shape: (84635, 5)
# Index(['class id', 'filepaths', 'labels', 'data set', 'scientific name'], dtype='object')
#    class id                      filepaths           labels data set  \
# 0       0.0  train/ABBOTTS BABBLER/001.jpg  ABBOTTS BABBLER    train
# 1       0.0  train/ABBOTTS BABBLER/007.jpg  ABBOTTS BABBLER    train
# 2       0.0  train/ABBOTTS BABBLER/008.jpg  ABBOTTS BABBLER    train
# 3       0.0  train/ABBOTTS BABBLER/009.jpg  ABBOTTS BABBLER    train
# 4       0.0  train/ABBOTTS BABBLER/002.jpg  ABBOTTS BABBLER    train
#
#         scientific name
# 0  MALACOCINCLA ABBOTTI
# 1  MALACOCINCLA ABBOTTI
# 2  MALACOCINCLA ABBOTTI
# 3  MALACOCINCLA ABBOTTI
# 4  MALACOCINCLA ABBOTTI
# test_df shape: (2625, 2)
# Index(['ID', 'FILE'], dtype='object')
#    ID               FILE
# 0   0  test_folder/0.jpg
# 1   1  test_folder/1.jpg
# 2   2  test_folder/2.jpg
# 3   3  test_folder/3.jpg
# 4   4  test_folder/4.jpg

# %%
#get actual class name
train_root = "/content/dataset/train/train"
actual_classes = set(os.listdir(train_root))
print("Danh sách class thực tế:", actual_classes)
# Out:
# Danh sách class thực tế: {'DOWNY WOODPECKER', 'RUDY KINGFISHER', 'IWI', 'CUBAN TROGON', 'ANDEAN SISKIN', 'FASCIATED WREN', 'GILDED FLICKER', 'ANTBIRD', 'CALIFORNIA CONDOR', 'AFRICAN OYSTER CATCHER', 'CHIPPING SPARROW', 'STRIATED CARACARA', 'NORTHERN GOSHAWK', 'GREAT TINAMOU', 'GREATOR SAGE GROUSE', 'RAZORBILL', 'BARN OWL', 'WATTLED CURASSOW', 'CHARA DE COLLAR', 'DUSKY LORY', 'ALEXANDRINE PARAKEET', 'BLACK SWAN', 'BANDED PITA', 'BEARDED BELLBIRD', 'GREY PLOVER', 'CRESTED CARACARA', 'AZURE TIT', 'SPOTTED WHISTLING DUCK', 'EASTERN WIP POOR WILL', 'CRESTED KINGFISHER', 'PURPLE FINCH', 'BUSH TURKEY', 'EURASIAN GOLDEN ORIOLE', 'BLACK THROATED BUSHTIT', 'VULTURINE GUINEAFOWL', 'TRICOLORED BLACKBIRD', 'NORTHERN JACANA', 'CAMPO FLICKER', 'CASSOWARY', 'WHITE BROWED CRAKE', 'STEAMER DUCK', 'VIOLET CUCKOO', 'BARROWS GOLDENEYE', 'CRAB PLOVER', 'KOOKABURRA', 'LOONEY BIRDS', 'INCA TERN', 'TASMANIAN HEN', 'TEAL DUCK', 'SHORT BILLED DOWITCHER', 'SHOEBILL', 'ALPINE CHOUGH', 'GREEN WINGED DOVE', 'NICOBAR PIGEON', 'DARJEELING WOODPECKER', 'CINNAMON ATTILA', 'BEARDED BARBET', 'HOOPOES', 'ECUADORIAN HILLSTAR', 'RUFOUS TREPE', 'AMERICAN DIPPER', 'DALMATIAN PELICAN', 'CHUKAR PARTRIDGE', 'COMMON FIRECREST', 'GAMBELS QUAIL', 'NORTHERN RED BISHOP', 'APAPANE', 'BORNEAN PHEASANT', 'ASIAN CRESTED IBIS', 'DUNLIN', 'ARARIPE MANAKIN', 'EMPEROR PENGUIN', 'GLOSSY IBIS', 'INDIAN VULTURE', 'EASTERN BLUEBONNET', 'VICTORIA CROWNED PIGEON', 'AMERICAN FLAMINGO', 'BIRD OF PARADISE', 'CREAM COLORED WOODPECKER', 'ABBOTTS BABBLER', 'KILLDEAR', 'PARUS MAJOR', 'ALBATROSS', 'GOLDEN CHLOROPHONIA', 'JABIRU', 'KING EIDER', 'PHILIPPINE EAGLE', 'ANNAS HUMMINGBIRD', 'MOURNING DOVE', 'ANDEAN GOOSE', 'COMMON LOON', 'OSTRICH', 'SRI LANKA BLUE MAGPIE', 'RUBY THROATED HUMMINGBIRD', 'ANIANIAU', 'FLAME TANAGER', 'INLAND DOTTEREL', 'AMERICAN PIPIT', 'MALLARD DUCK', 'VENEZUELIAN TROUPIAL', 'LESSER ADJUTANT', 'CINNAMON TEAL', 'SNOWY EGRET', 'EURASIAN MAGPIE', 'BLACK COCKATO', 'QUETZAL', 'BLUE COAU', 'CANARY', 'AMERICAN COOT', 'EASTERN BLUEBIRD', 'AFRICAN PIED HORNBILL', 'MASKED LAPWING', 'FIORDLAND PENGUIN', 'PURPLE GALLINULE', 'FLAME BOWERBIRD', 'COCK OF THE ROCK', 'BALI STARLING', 'IBERIAN MAGPIE', 'LOGGERHEAD SHRIKE', 'DUSKY ROBIN', 'ROCK DOVE', 'BANDED STILT', 'MALAGASY WHITE EYE', 'ALTAMIRA YELLOWTHROAT', 'BALD EAGLE', 'ELLIOTS PHEASANT', 'GURNEYS PITTA', 'NORTHERN SHOVELER', 'ELEGANT TROGON', 'SNOW GOOSE', 'AMERICAN REDSTART', 'AMERICAN AVOCET', 'INDIGO BUNTING', 'ROSEATE SPOONBILL', 'GREAT XENOPS', 'ABBOTTS BOOBY', 'AUCKLAND SHAQ', 'HEPATIC TANAGER', 'RED FACED CORMORANT', 'HORNED SUNGEM', 'BLACK FRANCOLIN', 'DAURIAN REDSTART', 'VIOLET TURACO', 'HAWFINCH', 'SNOWY OWL', 'CRESTED NUTHATCH', 'HAMERKOP', 'SORA', 'PALILA', 'BALD IBIS', 'BLACK-NECKED GREBE', 'BLACK THROATED HUET', 'WHITE EARED HUMMINGBIRD', 'VERDIN', 'VIOLET GREEN SWALLOW', 'EASTERN ROSELLA', 'BLACK-CAPPED CHICKADEE', 'FIRE TAILLED MYZORNIS', 'ANTILLEAN EUPHONIA', 'BULWERS PHEASANT', 'ORNATE HAWK EAGLE', 'SPOTTED CATBIRD', 'DOUBLE BARRED FINCH', 'ASIAN OPENBILL STORK', 'CARMINE BEE-EATER', 'BROWN CREPPER', 'UMBRELLA BIRD', 'RED HEADED WOODPECKER', 'BLACK SKIMMER', 'INDIAN ROLLER', 'HIMALAYAN MONAL', 'BLUE DACNIS', 'RUBY CROWNED KINGLET', 'SUNBITTERN', 'MANGROVE CUCKOO', 'GREY HEADED FISH EAGLE', 'PINK ROBIN', 'AZURE TANAGER', 'OSPREY', 'MILITARY MACAW', 'WHITE BREASTED WATERHEN', 'CRIMSON SUNBIRD', 'OCELLATED TURKEY', 'FAIRY PENGUIN', 'RED FODY', 'NORTHERN PARULA', 'CRESTED COUA', 'ORANGE BRESTED BUNTING', 'GRAY CATBIRD', 'WOOD DUCK', 'HYACINTH MACAW', 'BLUE GROUSE', 'CHUCAO TAPACULO', 'ALBERTS TOWHEE', 'NORTHERN MOCKINGBIRD', 'CHESTNET BELLIED EUPHONIA', 'CRESTED WOOD PARTRIDGE', 'GREY CUCKOOSHRIKE', 'GOLDEN PHEASANT', 'NORTHERN FULMAR', 'CHESTNUT WINGED CUCKOO', 'ASIAN GREEN BEE EATER', 'VARIED THRUSH', 'INDIAN BUSTARD', 'SCARLET FACED LIOCICHLA', 'SNOWY PLOVER', 'SCARLET CROWNED FRUIT DOVE', 'SQUACCO HERON', 'MALACHITE KINGFISHER', 'AZURE JAY', 'RING-NECKED PHEASANT', 'BLACK BREASTED PUFFBIRD', 'YELLOW BELLIED FLOWERPE ...

# %%
# get class name in csv
csv_classes = set(train_df["filepaths"].apply(lambda x: x.split("/")[1]))
print("Danh sách class trong CSV:", csv_classes)
# Out:
# Danh sách class trong CSV: {'DOWNY WOODPECKER', 'RUDY KINGFISHER', 'IWI', 'CUBAN TROGON', 'ANDEAN SISKIN', 'FASCIATED WREN', 'GILDED FLICKER', 'ANTBIRD', 'CALIFORNIA CONDOR', 'AFRICAN OYSTER CATCHER', 'CHIPPING SPARROW', 'STRIATED CARACARA', 'NORTHERN GOSHAWK', 'GREAT TINAMOU', 'GREATOR SAGE GROUSE', 'RAZORBILL', 'BARN OWL', 'WATTLED CURASSOW', 'CHARA DE COLLAR', 'DUSKY LORY', 'PARAKETT AKULET', 'ALEXANDRINE PARAKEET', 'BLACK SWAN', 'BANDED PITA', 'BEARDED BELLBIRD', 'CRESTED CARACARA', 'GREY PLOVER', 'AZURE TIT', 'CRESTED KINGFISHER', 'EASTERN WIP POOR WILL', 'PURPLE FINCH', 'SPOTTED WHISTLING DUCK', 'BUSH TURKEY', 'EURASIAN GOLDEN ORIOLE', 'BLACK THROATED BUSHTIT', 'VULTURINE GUINEAFOWL', 'TRICOLORED BLACKBIRD', 'NORTHERN JACANA', 'CAMPO FLICKER', 'CASSOWARY', 'WHITE BROWED CRAKE', 'STEAMER DUCK', 'VIOLET CUCKOO', 'BARROWS GOLDENEYE', 'CRAB PLOVER', 'KOOKABURRA', 'LOONEY BIRDS', 'INCA TERN', 'TASMANIAN HEN', 'SHOEBILL', 'SHORT BILLED DOWITCHER', 'ALPINE CHOUGH', 'TEAL DUCK', 'GREEN WINGED DOVE', 'NICOBAR PIGEON', 'DARJEELING WOODPECKER', 'CINNAMON ATTILA', 'BEARDED BARBET', 'HOOPOES', 'ECUADORIAN HILLSTAR', 'RUFOUS TREPE', 'AMERICAN DIPPER', 'CHUKAR PARTRIDGE', 'DALMATIAN PELICAN', 'COMMON FIRECREST', 'GAMBELS QUAIL', 'NORTHERN RED BISHOP', 'APAPANE', 'BORNEAN PHEASANT', 'ASIAN CRESTED IBIS', 'DUNLIN', 'ARARIPE MANAKIN', 'EMPEROR PENGUIN', 'GLOSSY IBIS', 'INDIAN VULTURE', 'EASTERN BLUEBONNET', 'VICTORIA CROWNED PIGEON', 'AMERICAN FLAMINGO', 'BIRD OF PARADISE', 'CREAM COLORED WOODPECKER', 'ABBOTTS BABBLER', 'KILLDEAR', 'PARUS MAJOR', 'ALBATROSS', 'GOLDEN CHLOROPHONIA', 'JABIRU', 'KING EIDER', 'PHILIPPINE EAGLE', 'ANNAS HUMMINGBIRD', 'MOURNING DOVE', 'ANDEAN GOOSE', 'COMMON LOON', 'OSTRICH', 'SRI LANKA BLUE MAGPIE', 'RUBY THROATED HUMMINGBIRD', 'ANIANIAU', 'FLAME TANAGER', 'INLAND DOTTEREL', 'AMERICAN PIPIT', 'MALLARD DUCK', 'VENEZUELIAN TROUPIAL', 'LESSER ADJUTANT', 'CINNAMON TEAL', 'SNOWY EGRET', 'EURASIAN MAGPIE', 'BLACK COCKATO', 'QUETZAL', 'BLUE COAU', 'AMERICAN COOT', 'CANARY', 'EASTERN BLUEBIRD', 'AFRICAN PIED HORNBILL', 'MASKED LAPWING', 'FIORDLAND PENGUIN', 'PURPLE GALLINULE', 'FLAME BOWERBIRD', 'COCK OF THE ROCK', 'BALI STARLING', 'IBERIAN MAGPIE', 'LOGGERHEAD SHRIKE', 'DUSKY ROBIN', 'ROCK DOVE', 'BANDED STILT', 'ALTAMIRA YELLOWTHROAT', 'MALAGASY WHITE EYE', 'MASKED BOBWHITE', 'BALD EAGLE', 'ELLIOTS PHEASANT', 'GURNEYS PITTA', 'NORTHERN SHOVELER', 'ELEGANT TROGON', 'SNOW GOOSE', 'AMERICAN AVOCET', 'AMERICAN REDSTART', 'INDIGO BUNTING', 'GREAT XENOPS', 'ABBOTTS BOOBY', 'ROSEATE SPOONBILL', 'AUCKLAND SHAQ', 'HEPATIC TANAGER', 'RED FACED CORMORANT', 'HORNED SUNGEM', 'BLACK FRANCOLIN', 'DAURIAN REDSTART', 'VIOLET TURACO', 'HAWFINCH', 'SNOWY OWL', 'CRESTED NUTHATCH', 'HAMERKOP', 'SORA', 'PALILA', 'BALD IBIS', 'BLACK-NECKED GREBE', 'BLACK THROATED HUET', 'WHITE EARED HUMMINGBIRD', 'VERDIN', 'EASTERN ROSELLA', 'VIOLET GREEN SWALLOW', 'BLACK-CAPPED CHICKADEE', 'FIRE TAILLED MYZORNIS', 'ANTILLEAN EUPHONIA', 'BULWERS PHEASANT', 'ORNATE HAWK EAGLE', 'SPOTTED CATBIRD', 'DOUBLE BARRED FINCH', 'ASIAN OPENBILL STORK', 'CARMINE BEE-EATER', 'BROWN CREPPER', 'UMBRELLA BIRD', 'BLACK SKIMMER', 'RED HEADED WOODPECKER', 'INDIAN ROLLER', 'BLUE DACNIS', 'HIMALAYAN MONAL', 'RUBY CROWNED KINGLET', 'SUNBITTERN', 'MANGROVE CUCKOO', 'GREY HEADED FISH EAGLE', 'AZURE TANAGER', 'MILITARY MACAW', 'OSPREY', 'PINK ROBIN', 'WHITE BREASTED WATERHEN', 'CRIMSON SUNBIRD', 'OCELLATED TURKEY', 'FAIRY PENGUIN', 'RED FODY', 'NORTHERN PARULA', 'CRESTED COUA', 'ORANGE BRESTED BUNTING', 'GRAY CATBIRD', 'HYACINTH MACAW', 'WOOD DUCK', 'ALBERTS TOWHEE', 'BLUE GROUSE', 'CHESTNET BELLIED EUPHONIA', 'CHUCAO TAPACULO', 'NORTHERN MOCKINGBIRD', 'CRESTED WOOD PARTRIDGE', 'GREY CUCKOOSHRIKE', 'GOLDEN PHEASANT', 'NORTHERN FULMAR', 'CHESTNUT WINGED CUCKOO', 'ASIAN GREEN BEE EATER', 'VARIED THRUSH', 'INDIAN BUSTARD', 'SCARLET FACED LIOCICHLA', 'SNOWY PLOVER', 'SCARLET CROWNED FRUIT DOVE', 'SQUACCO HERON', 'MALACHITE KINGFISHER', 'AZURE JAY', 'RING-NECKED PHEASANT', 'BLACK BREA ...

# %%
# check misspelling
wrong_classes = csv_classes - actual_classes
print("Những class bị sai chính tả:", wrong_classes)
# Out:
# Những class bị sai chính tả: {'PARAKETT AKULET'}

# %%
bad_rows = []
for i in range(len(train_df)):
    fp = train_df.loc[i, "filepaths"]
    full_path = os.path.join("/content/dataset/train", fp)
    if not os.path.exists(full_path):
        bad_rows.append(i)

print(f"Số dòng filepaths không tìm thấy file: {len(bad_rows)}")

# view some in them
if len(bad_rows) > 0:
    print("Ví dụ các dòng bị lỗi:")
    display(train_df.loc[bad_rows].head(10))

# if missing, let's change them
for i in bad_rows:
    fp = train_df.loc[i, "filepaths"]
    new_fp = "train/" + fp
    full_path = os.path.join("/content/dataset", new_fp)
    if os.path.exists(full_path):
        train_df.loc[i, "filepaths"] = new_fp
# Out:
# Số dòng filepaths không tìm thấy file: 155
# Ví dụ các dòng bị lỗi:
#        class id                      filepaths            labels data set  \
# 59400     373.0  train/PARAKETT AKULET/038.jpg  PARAKETT  AKULET    train
# 59401     373.0  train/PARAKETT AKULET/079.jpg  PARAKETT  AKULET    train
# 59402     373.0  train/PARAKETT AKULET/137.jpg  PARAKETT  AKULET    train
# 59403     373.0  train/PARAKETT AKULET/128.jpg  PARAKETT  AKULET    train
# 59404     373.0  train/PARAKETT AKULET/005.jpg  PARAKETT  AKULET    train
# 59405     373.0  train/PARAKETT AKULET/015.jpg  PARAKETT  AKULET    train
# 59406     373.0  train/PARAKETT AKULET/018.jpg  PARAKETT  AKULET    train
# 59407     373.0  train/PARAKETT AKULET/077.jpg  PARAKETT  AKULET    train
# 59408     373.0  train/PARAKETT AKULET/007.jpg  PARAKETT  AKULET    train
# 59409     373.0  train/PARAKETT AKULET/011.jpg  PARAKETT  AKULET    train
#
#          scientific name
# 59400  AETHIA PSITTACULA
# 59401  AETHIA PSITTACULA
# 59402  AETHIA PSITTACULA
# 59403  AETHIA PSITTACULA
# 59404  AETHIA PSITTACULA
# 59405  AETHIA PSITTACULA
# 59406  AETHIA PSITTACULA
# 59407  AETHIA PSITTACULA
# 59408  AETHIA PSITTACULA
# 59409  AETHIA PSITTACULA

# %%
# let's review class names on train dataset
# !ls "/content/dataset/train/train"
# Out:
# 'ABBOTTS BABBLER'	      'CRESTED SERPENT EAGLE'	  'MOURNING DOVE'
# 'ABBOTTS BOOBY'		      'CRESTED SHRIKETIT'	   MYNA
# 'ABYSSINIAN GROUND HORNBILL'  'CRESTED WOOD PARTRIDGE'	  'NICOBAR PIGEON'
# 'AFRICAN CROWNED CRANE'       'CRIMSON CHAT'		  'NOISY FRIARBIRD'
# 'AFRICAN EMERALD CUCKOO'      'CRIMSON SUNBIRD'		  'NORTHERN BEARDLESS TYRANNULET'
# 'AFRICAN FIREFINCH'	       CROW			  'NORTHERN CARDINAL'
# 'AFRICAN OYSTER CATCHER'      'CUBAN TODY'		  'NORTHERN FLICKER'
# 'AFRICAN PIED HORNBILL'       'CUBAN TROGON'		  'NORTHERN FULMAR'
# 'AFRICAN PYGMY GOOSE'	      'CURL CRESTED ARACURI'	  'NORTHERN GANNET'
#  ALBATROSS		      'DALMATIAN PELICAN'	  'NORTHERN GOSHAWK'
# 'ALBERTS TOWHEE'	      'DARJEELING WOODPECKER'	  'NORTHERN JACANA'
# 'ALEXANDRINE PARAKEET'	      'DARK EYED JUNCO'		  'NORTHERN MOCKINGBIRD'
# 'ALPINE CHOUGH'		      'D-ARNAUDS BARBET'	  'NORTHERN PARULA'
# 'ALTAMIRA YELLOWTHROAT'       'DAURIAN REDSTART'	  'NORTHERN RED BISHOP'
# 'AMERICAN AVOCET'	      'DEMOISELLE CRANE'	  'NORTHERN SHOVELER'
# 'AMERICAN BITTERN'	      'DOUBLE BARRED FINCH'	  'OCELLATED TURKEY'
# 'AMERICAN COOT'		      'DOUBLE BRESTED CORMARANT'   OILBIRD
# 'AMERICAN DIPPER'	      'DOUBLE EYED FIG PARROT'	  'OKINAWA RAIL'
# 'AMERICAN FLAMINGO'	      'DOWNY WOODPECKER'	  'ORANGE BREASTED TROGON'
# 'AMERICAN GOLDFINCH'	       DUNLIN			  'ORANGE BRESTED BUNTING'
# 'AMERICAN KESTREL'	      'DUSKY LORY'		  'ORIENTAL BAY OWL'
# 'AMERICAN PIPIT'	      'DUSKY ROBIN'		  'ORNATE HAWK EAGLE'
# 'AMERICAN REDSTART'	      'EARED PITA'		   OSPREY
# 'AMERICAN ROBIN'	      'EASTERN BLUEBIRD'	   OSTRICH
# 'AMERICAN WIGEON'	      'EASTERN BLUEBONNET'	   OVENBIRD
# 'AMETHYST WOODSTAR'	      'EASTERN GOLDEN WEAVER'	  'OYSTER CATCHER'
# 'ANDEAN GOOSE'		      'EASTERN MEADOWLARK'	  'PAINTED BUNTING'
# 'ANDEAN LAPWING'	      'EASTERN ROSELLA'		   PALILA
# 'ANDEAN SISKIN'		      'EASTERN TOWEE'		  'PALM NUT VULTURE'
#  ANHINGA		      'EASTERN WIP POOR WILL'	  'PARADISE TANAGER'
#  ANIANIAU		      'EASTERN YELLOW ROBIN'	  'PARAKETT AUKLET'
# 'ANNAS HUMMINGBIRD'	      'ECUADORIAN HILLSTAR'	  'PARUS MAJOR'
#  ANTBIRD		      'EGYPTIAN GOOSE'		  'PATAGONIAN SIERRA FINCH'
# 'ANTILLEAN EUPHONIA'	      'ELEGANT TROGON'		   PEACOCK
#  APAPANE		      'ELLIOTS PHEASANT'	  'PEREGRINE FALCON'
#  APOSTLEBIRD		      'EMERALD TANAGER'		   PHAINOPEPLA
# 'ARARIPE MANAKIN'	      'EMPEROR PENGUIN'		  'PHILIPPINE EAGLE'
# 'ASHY STORM PETREL'	       EMU			  'PINK ROBIN'
# 'ASHY THRUSHBIRD'	      'ENGGANO MYNA'		  'PLUSH CRESTED JAY'
# 'ASIAN CRESTED IBIS'	      'EURASIAN BULLFINCH'	  'POMARINE JAEGER'
# 'ASIAN DOLLARD BIRD'	      'EURASIAN GOLDEN ORIOLE'	   PUFFIN
# 'ASIAN GREEN BEE EATER'       'EURASIAN MAGPIE'		  'PUNA TEAL'
# 'ASIAN OPENBILL STORK'	      'EUROPEAN GOLDFINCH'	  'PURPLE FINCH'
# 'AUCKLAND SHAQ'		      'EUROPEAN TURTLE DOVE'	  'PURPLE GALLINULE'
# 'AUSTRALASIAN FIGBIRD'	      'EVENING GROSBEAK'	  'PURPLE MARTIN'
# 'AUSTRAL CANASTERO'	      'FAIRY BLUEBIRD'		  'PURPLE SWAMPHEN'
#  AVADAVAT		      'FAIRY PENGUIN'		  'PYGMY KINGFISHER'
# 'AZARAS SPINETAIL'	      'FAIRY TERN'		   PYRRHULOXIA
# 'AZURE BREASTED PITTA'	      'FAN TAILED WIDOW'	   QUETZAL
# 'AZURE JAY'		      'FASCIATED WREN'		  'RAINBOW LORIKEET'
# 'AZURE TANAGER'		      'FIERY MINIVET'		   RAZORBILL
# 'AZURE TIT'		      'FIORDLAND PENGUIN'	  'RED BEARDED BEE EATER'
# 'BAIKAL TEAL'		      'FIRE TAILLED MYZORNIS'	  'RED BELLIED PITTA'
# 'BALD EAGLE'		      'FLAME BOWERBIRD'		  'RED BILLED TROPICBIRD'
# 'BALD IBIS'		      'FLAME TANAGER'		  'RED BROWED FINCH'
# 'BALI STARLING'		      'FOREST WAGTAIL'		  'RED CROSSBILL'
# 'BALTIMORE ORIOLE'	       FRIGATE			  'RED FACED CORMORANT'
#  BANANAQUIT		      'FRILL BACK PIGEON'	  'RED FACED WARBLER'
# 'BANDED BROADBILL'	      'GAMBELS QUAIL'		  'RED FODY'
# 'BANDED PITA'		      'GANG GANG COCKATOO'	  'RED HEADED DUCK'
# 'BANDED STILT'		      'GILA WOODPECKER'		  'RED HEADED WOODPECKER'
# 'BAND TAILED GUAN'	      'GILDED FLICKER'		  'RED KNOT'
# 'BARN OWL'		      'GLOSSY IBIS'		  'RED LEGGED HONEYCREEPER'
# 'BARN SWALLOW'		      'GO AWAY BIRD'		  'RED NAPED TROGON'
# 'BARRED PUFFBIRD'	      'GOLDEN BOWER BIRD'	  'RED SHOULDERED HAWK'
# 'BARROWS GOLDENEYE'	      'GOLDEN CHEEKED WARBLER'	  'RED TAILED HAWK'
# 'BAR-TAILED GODWIT'	      'GOLDEN CHLOROPHONIA'	  'RED TAILED THRUSH'
# 'BAY-BREASTED WARBLER'	      'GOLDEN EAGLE'		  'RED WINGED BLACKBIRD'
# 'BEARDED BARBET'	      'GOLDEN PARAKEET'		  'RED WISKERED BULBUL'
# 'BEARDED BELLBIRD'	      'GOLDEN PHEASANT'		  'REGENT BOWERBIRD'
# 'BEARDED REEDLING'	      'GOLDEN PIPIT'		  'RING-NECKED PHEASANT'
# 'BELTED KINGFISHER'	      'GOLD WING WARBLER'	   ROADRUNNER
# 'BIRD OF PARADISE'	      'GOULDIAN FINCH'		  'ROCK DOVE'
# 'BLACK AND YELLOW BROADBILL'   GRANDALA			  'ROSEATE SPOONBILL'
# 'BLACK BAZA'		      'GRAY CATBIRD'		  'ROSE BREASTED COCKATOO'
# 'BLACK BREASTED PUFFBIRD'     'GRAY KINGBIRD'		  'ROSE BREASTED GROSBEAK'
# 'BLACKBURNIAM WARBLER'	      'GRAY PARTRIDGE'		  'ROSY FACED LOVEBIRD'
# 'BLACK-CAPPED CHICKADEE'      'GREAT ARGUS'		  'ROUGH LEG BUZZARD'
# 'BLACK COCKATO'		      'GREATER PEWEE'		  'ROYAL FLYCATCHER'
# 'BLACK FACED SPOONBILL'       'GREATER PRAIRIE CHICKEN'   'RUBY CROWNED KINGLET'
# 'BLACK FRANCOLIN'	      'GREAT GRAY OWL'		  'RUBY THROATED HUMMINGBIRD'
# 'BLACK HEADED CAIQUE'	      'GREAT JACAMAR'		  'RUDDY SHELDUCK'
# 'BLACK-NECKED GREBE'	      'GREAT KISKADEE'		  'RUDY KINGFISHER'
# 'BLACK NECKED STILT'	      'GREATOR SAGE GROUSE'	  'RUFOUS KINGFISHER'
# 'BLACK SKIMMER'		      'GREAT POTOO'		  'RUFOUS TREPE'
# 'BLACK SWAN'		      'GREAT TINAMOU'		  'RUFUOS MOTMOT'
# 'BLACK TAIL CRAKE'	      'GREAT XENOPS'		  'SAMATRAN THRUSH'
# 'BLACK THROATED BUSHTIT'      'GREEN BROADBILL'		  'SANDHILL CRANE'
# 'BLACK THROATED HUET'	      'GREEN JAY'		  'SAND MARTIN'
# 'BLACK-THROATED SPARROW'      'GREEN MAGPIE'		  'SATYR TRAGOPAN'
# 'BLACK THROATED WARBLER'      'GREEN WINGED DOVE'	  'SAYS PHOEBE'
# 'BLACK VENTED SHEARWATER'     'GREY CUCKOOSHRIKE'	  'SCARLET CROWNED FRUIT DOVE'
# 'BLACK VULTURE'		      'GREY HEADED CHACHALACA'	  'SCARLET FACED LIOCICHLA'
# 'BLONDE CRESTED WOODPECKER'   'GREY HEADED FISH EAGLE'	  'SCARLET IBIS'
# 'BLOOD PHEASANT'	      'GREY PLOVER'		  'SCARLET MACAW'
# 'BLUE COAU'		      'GROVED BILLED ANI'	  'SCARLET TANAGER'
# 'BLUE DACNIS'		       GUINEAFOWL		   SHOEBILL
# 'BLUE GRAY GNATCATCHER'       'GUINEA TURACO'		  'SHORT BILLED DOWITCHER'
# 'BLUE GROSBEAK'		      'GURNEYS PITTA'		  'SMITHS LONGSPUR'
# 'BLUE GROUSE'		       GYRFALCON		  'SNOW GOOSE'
# 'BLUE HERON'		       HAMERKOP			  'SNOW PARTRIDGE'
# 'BLUE MALKOHA'		      'HARLEQUIN DUCK'		  'SNOWY EGRET'
# 'BLUE THROATED PIPING GUAN'   'HARLEQUIN QUAIL'		  'SNOWY OWL'
# 'BLUE THROATED TOUCANET'      'HARPY EAGLE'		  'SNOWY PLOVER'
#  BOBOLINK		      'HAWAIIAN GOOSE'		  'SNOWY SHEATHBILL'
# 'BORNEAN BRISTLEHEAD'	       HAWFINCH			   SORA
# 'BORNEAN LEAFBIRD'	      'HELMET VANGA'		  'SPANGLED COTINGA'
# 'BORNEAN PHEASANT'	      'HEPATIC TANAGER'		  'SPLENDID WREN'
# 'BRANDT CORMARANT'	      'HIMALAYAN BLUETAIL'	  'SPOON BILED SANDPIPER'
# 'BREWERS BLACKBIRD'	      'HIMALAYAN MONAL'		  'SPOTTED CATBIRD'
# 'BROWN CREPPER'		       HOATZIN			  'SPOTTED WHISTLING DUCK'
# 'BROWN HEADED COWBIRD'	      'HOODED MERGANSER'	  'SQUACCO HERON'
# 'BROWN NOODY'		       HOOPOES			  'SRI LANKA BLUE MAGPIE'
# 'BROWN THRASHER'	      'HORNED GUAN'		  'STEAMER DUCK'
#  BUFFLEHEAD		      'HORNED LARK'		  'STORK BILLED KINGFISHER'
# 'BULWERS PHEASANT'	      'HORNED SUNGEM'		  'STRIATED CARACARA'
# 'BURCHELLS COURSER'	      'HOUSE FINCH'		  'STRIPED OWL'
# 'BUSH TURKEY'		      'HOUSE SPARROW'		  'STRIPPED MANAKIN'
# 'CAATINGA CACHOLOTE'	      'HYACINTH MACAW'		  'STRIPPED SWALLOW'
# 'CABOTS TRAGOPAN'	      'IBERIAN MAGPIE'		   SUNBITTERN
# 'CACTUS WREN'		       IBISBILL			  'SUPERB STARLING'
# 'CALIFORNIA CONDOR'	      'IMPERIAL SHAQ'		  'SURF SCOTER'
# 'CALIFORNIA GULL'	      'INCA TERN'		  'SWINHOES PHEASANT'
# 'CALIFORNIA QUAIL'	      'INDIAN BUSTARD'		   TAILORBIRD
# 'CAMPO FLICKER'		      'INDIAN PITTA'		  'TAIWAN MAGPIE'
#  CANARY			      'INDIAN ROLLER'		   TAKAHE
#  CANVASBACK		      'INDIAN VULTURE'		  'TASMANIAN HEN'
# 'CAPE GLOSSY STARLING'	      'INDIGO BUNTING'		  'TAWNY FROGMOUTH'
# 'CAPE LONGCLAW'		      'INDIGO FLYCATCHER'	  'TEAL DUCK'
# 'CAPE MAY WARBLER'	      'INLAND DOTTEREL'		  'TIT MOUSE'
# 'CAPE ROCK THRUSH'	      'IVORY BILLED ARACARI'	   TOUCHAN
# 'CAPPED HERON'		      'IVORY GULL'		  'TOWNSENDS WARBLER'
#  CAPUCHINBIRD		       IWI			  'TREE SWALLOW'
# 'CARMINE BEE-EATER'	       JABIRU			  'TRICOLORED BLACKBIRD'
# 'CASPIAN TERN'		      'JACK SNIPE'		  'TROPICAL KINGBIRD'
#  CASSOWARY		      'JACOBIN PIGEON'		  'TRUMPTER SWAN'
# 'CEDAR WAXWING'		      'JANDAYA PARAKEET'	  'TURKEY VULTURE'
# 'CERULEAN WARBLER'	      'JAPANESE ROBIN'		  'TURQUOISE MOTMOT'
# 'CHARA DE COLLAR'	      'JAVA SPARROW'		  'UMBRELLA BIRD'
# 'CHATTERING LORY'	      'JOCOTOCO ANTPITTA'	  'VARIED THRUSH'
# 'CHESTNET BELLIED EUPHONIA'    KAGU			   VEERY
# 'CHESTNUT WINGED CUCKOO'       KAKAPO			  'VENEZUELIAN TROUPIAL'
# 'CHINESE BAMBOO PARTRIDGE'     KILLDEAR			   VERDIN
# 'CHINESE POND HERON'	      'KING EIDER'		  'VERMILION FLYCATHER'
# 'CHIPPING SPARROW'	      'KING VULTURE'		  'VICTORIA CROWNED PIGEON'
# 'CHUCAO TAPACULO'	       KIWI			  'VIOLET BACKED STARLING'
# 'CHUKAR PARTRIDGE'	      'KNOB BILLED DUCK'	  'VIOLET CUCKOO'
# 'CINNAMON ATTILA'	       KOOKABURRA		  'VIOLET GREEN SWALLOW'
# 'CINNAMON FLYCATCHER'	      'LARK BUNTING'		  'VIOLET TURACO'
# 'CINNAMON TEAL'		      'LAUGHING GULL'		  'VISAYAN HORNBILL'
# 'CLARKS GREBE'		      'LAZULI BUNTING'		  'VULTURINE GUINEAFOWL'
# 'CLARKS NUTCRACKER'	      'LESSER ADJUTANT'		  'WALL CREAPER'
#  COCKATOO		      'LILAC ROLLER'		  'WATTLED CURASSOW'
# 'COCK OF THE ROCK'	       LIMPKIN			  'WATTLED LAPWING'
# 'COLLARED ARACARI'	      'LITTLE AUK'		   WHIMBREL
# 'COLLARED CRESCENTCHEST'      'LOGGERHEAD SHRIKE'	  'WHITE BREASTED WATERHEN'
# 'COMMON FIRECREST'	      'LONG-EARED OWL'		  'WHITE BROWED CRAKE'
# 'COMMON GRACKLE'	      'LOONEY BIRDS'		  'WHITE CHEEKED TURACO'
# 'COMMON HOUSE MARTIN'	      'LUCIFER HUMMINGBIRD'	  'WHITE CRESTED HORNBILL'
# 'COMMON IORA'		      'MAGPIE GOOSE'		  'WHITE EARED HUMMINGBIRD'
# 'COMMON LOON'		      'MALABAR HORNBILL'	  'WHITE NECKED RAVEN'
# 'COMMON POORWILL'	      'MALACHITE KINGFISHER'	  'WHITE TAILED TROPIC'
# 'COMMON STARLING'	      'MALAGASY WHITE EYE'	  'WHITE THROATED BEE EATER'
# 'COPPERSMITH BARBET'	       MALEO			  'WILD TURKEY'
# 'COPPERY TAILED COUCAL'       'MALLARD DUCK'		  'WILLOW PTARMIGAN'
# 'CRAB PLOVER'		      'MANDRIN DUCK'		  'WILSONS BIRD OF PARADISE'
# 'CRANE HAWK'		      'MANGROVE CUCKOO'		  'WOOD DUCK'
# 'CREAM COLORED WOODPECKER'    'MARABOU STORK'		  'WOODLAND KINGFISHER'
# 'CRESTED AUKLET'	      'MASKED BOBWHITE'		  'WOOD THRUSH'
# 'CRESTED CARACARA'	      'MASKED BOOBY'		   WRENTIT
# 'CRESTED COUA'		      'MASKED LAPWING'		  'YELLOW BELLIED FLOWERPECKER'
# 'CRESTED FIREBACK'	      'MCKAYS BUNTING'		  'YELLOW BREASTED CHAT'
# 'CRESTED KINGFISHER'	       MERLIN			  'YELLOW CACIQUE'
# 'CRESTED NUTHATCH'	      'MIKADO PHEASANT'		  'YELLOW HEADED BLACKBIRD'
# 'CRESTED OROPENDOLA'	      'MILITARY MACAW'		  'ZEBRA DOVE'

# %%
#fix misspelling
train_df["filepaths"] = train_df["filepaths"].str.replace("PARAKETT AKULET", "PARAKETT AUKLET")

# %%
#check again
# !ls "/content/dataset/train/train/PARAKETT AUKLET"
# Out:
# 001.jpg  016.jpg  031.jpg  046.jpg  061.jpg  076.jpg  091.jpg  106.jpg	121.jpg  136.jpg  151.jpg
# 002.jpg  017.jpg  032.jpg  047.jpg  062.jpg  077.jpg  092.jpg  107.jpg	122.jpg  137.jpg  152.jpg
# 003.jpg  018.jpg  033.jpg  048.jpg  063.jpg  078.jpg  093.jpg  108.jpg	123.jpg  138.jpg  153.jpg
# 004.jpg  019.jpg  034.jpg  049.jpg  064.jpg  079.jpg  094.jpg  109.jpg	124.jpg  139.jpg  154.jpg
# 005.jpg  020.jpg  035.jpg  050.jpg  065.jpg  080.jpg  095.jpg  110.jpg	125.jpg  140.jpg  155.jpg
# 006.jpg  021.jpg  036.jpg  051.jpg  066.jpg  081.jpg  096.jpg  111.jpg	126.jpg  141.jpg
# 007.jpg  022.jpg  037.jpg  052.jpg  067.jpg  082.jpg  097.jpg  112.jpg	127.jpg  142.jpg
# 008.jpg  023.jpg  038.jpg  053.jpg  068.jpg  083.jpg  098.jpg  113.jpg	128.jpg  143.jpg
# 009.jpg  024.jpg  039.jpg  054.jpg  069.jpg  084.jpg  099.jpg  114.jpg	129.jpg  144.jpg
# 010.jpg  025.jpg  040.jpg  055.jpg  070.jpg  085.jpg  100.jpg  115.jpg	130.jpg  145.jpg
# 011.jpg  026.jpg  041.jpg  056.jpg  071.jpg  086.jpg  101.jpg  116.jpg	131.jpg  146.jpg
# 012.jpg  027.jpg  042.jpg  057.jpg  072.jpg  087.jpg  102.jpg  117.jpg	132.jpg  147.jpg
# 013.jpg  028.jpg  043.jpg  058.jpg  073.jpg  088.jpg  103.jpg  118.jpg	133.jpg  148.jpg
# 014.jpg  029.jpg  044.jpg  059.jpg  074.jpg  089.jpg  104.jpg  119.jpg	134.jpg  149.jpg
# 015.jpg  030.jpg  045.jpg  060.jpg  075.jpg  090.jpg  105.jpg  120.jpg	135.jpg  150.jpg

# %%
# split train dataset -> train and valid
train_df_split, val_df_split = train_test_split(train_df, test_size=0.2, random_state=42, stratify=train_df["class id"])

# %% [markdown]
# ##custom dataset for train/validation

# %%
#custom dataset
class BirdDataset(Dataset):
  def __init__(self, df, img_dir, transform=None):
    """
    csv_file: đường dẫn đến file csv
    img_dir: đường dẫn đến thư mục chứa ảnh)
    transform: transform áp dụng cho ảnh
    """
    self.df = df.reset_index(drop=True)
    self.img_dir = img_dir
    self.transform = transform

  def __len__(self):
    return len(self.df)

  def __getitem__(self, idx):
    image_path = os.path.join(self.img_dir, self.df.loc[idx, "filepaths"])
    label = self.df.loc[idx, 'class id']

    #open image with PIL, convert to RGB
    image = Image.open(image_path).convert("RGB")
    if self.transform:
      image = self.transform(image)

    return image, label

# %%
#transform for train: resize, random flip, to tensor and normalize
img_size = 224

train_transform = transforms.Compose([
    transforms.Resize((img_size, img_size)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
#transform for test
test_transform = transforms.Compose([
    transforms.Resize((img_size, img_size)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# %%
#train_test_spit
train_df_split, val_df_split = train_test_split(
    train_df,
    test_size=0.2,
    random_state=42,
    stratify=train_df["class id"]
)

print(f"train_df_split shape: {train_df_split.shape}")
print(f"val_df_split shape: {val_df_split.shape}")
# Out:
# train_df_split shape: (67708, 5)
# val_df_split shape: (16927, 5)

# %%
#dataset and dataloader

#dataset
train_dataset = BirdDataset(train_df_split, img_dir="/content/dataset/train", transform=train_transform)
val_dataset = BirdDataset(val_df_split, img_dir="/content/dataset/train", transform=test_transform)

#dataloader
batch_size=32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

print(f"train_dataset size: {len(train_dataset)}")
print(f"val_dataset size: {len(val_dataset)}")
# Out:
# train_dataset size: 67708
# val_dataset size: 16927

# %% [markdown]
# ##Xây dựng mô hình với Transfer Learning (EfficientNet_B0)

# %%
num_classes =525

#load EfficientNet_B0
model = models.efficientnet_b0(pretrained=True)

#Freeze base params of model (change classifier)
for param in model.parameters():
  param.requires_grad = False

in_features = model.classifier[1].in_features
model.classifier[1] = nn.Linear(in_features, num_classes)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
print(model)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 57.9MB/s]
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=True)
#     (1): Linear(in_features=1280, out_features=525, bias=True)
#   )
# )

# %%
#optim and loss func
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

# %%
#define train and eval model
def train_epochs(model, loader, optimizer, criterion, device):
  model.train()
  running_loss = 0.0
  correct = 0
  total = 0

  for images, labels in loader:
    images, labels = images.to(device), labels.to(device)
    labels = labels.type(torch.int64)
    optimizer.zero_grad()

    outputs = model(images)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    running_loss += loss.item() * images.size(0)
    _, preds = torch.max(outputs, 1)
    correct += torch.sum(preds == labels.data)
    total += labels.size(0)

  e_loss = running_loss / total
  e_acc = correct.double().item() / total
  return e_loss, e_acc

# %%
#define evaluate
def evaluate(model, loader, criterion, device):
  model.eval()
  running_loss = 0.0
  correct = 0
  total = 0

  with torch.no_grad():
    for images, labels in loader:
      images, labels = images.to(device), labels.to(device)
      labels = labels.type(torch.LongTensor).to(device)
      outputs = model(images)
      loss = criterion(outputs, labels)

      running_loss += loss.item() * images.size(0)
      _, preds = torch.max(outputs, 1)
      correct += torch.sum(preds == labels.data)
      total += labels.size(0)

  e_loss = running_loss / total
  e_acc = correct.double().item() / total
  return e_loss, e_acc

# %%
#check type before print loss and accuracy
print("Type of train_loss:", type(train_loss))
print("Type of train_acc:", type(train_acc))
print("Type of val_loss:", type(val_loss))
print("Type of val_acc:", type(val_acc))
# Out:
# Type of train_loss: <class 'float'>
# Type of train_acc: <class 'list'>
# Type of val_loss: <class 'float'>
# Type of val_acc: <class 'float'>

# %%
#print loss and accuracy
epochs = 4
train_losses, val_losses = [], []
train_accs, val_accs = [], []

for epoch in range(epochs):
  train_loss, train_acc = train_epochs(model, train_loader, optimizer, criterion, device)
  val_loss, val_acc = evaluate(model, val_loader, criterion, device)

  train_losses.append(train_loss)
  val_losses.append(val_loss)
  train_accs.append(train_acc)
  val_accs.append(val_acc)
  print(f"Epoch: {epoch+1}/{epochs}")
  print(f"Train Loss: {train_loss:.4f} - Train Acc: {train_acc:.4f}")
  print(f"Val Loss: {val_loss:.4f} - Val Acc: {val_acc:.4f}")


  scheduler.step()
# Out:
# Epoch: 1/4
# Train Loss: 0.2762 - Train Acc: 0.9233
# Val Loss: 0.5847 - Val Acc: 0.8573
# Epoch: 2/4
# Train Loss: 0.2660 - Train Acc: 0.9257
# Val Loss: 0.5983 - Val Acc: 0.8571
# Epoch: 3/4
# Train Loss: 0.2482 - Train Acc: 0.9297
# Val Loss: 0.6062 - Val Acc: 0.8563
# Epoch: 4/4
# Train Loss: 0.2416 - Train Acc: 0.9305
# Val Loss: 0.5905 - Val Acc: 0.8619

# %%
#visualize result
plt.figure(figsize=(12,5))

#plot loss
plt.subplot(1,2,1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Val Loss')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss over Epoch")
plt.legend()

#plot accuracy
plt.subplot(1,2,2)
plt.plot(train_accs, label='Train Acc')
plt.plot(val_accs, label='Val Acc')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy over Epoch")
plt.legend()

plt.show()

# %%
#save model
os.makedirs("/content/models", exist_ok=True)
model_path = "/content/models/best_model.pth"
torch.save(model.state_dict(), model_path)
print(f"Mô hình đã được lưu tại: {model_path}")
# Out:
# Mô hình đã được lưu tại: /content/models/best_model.pth

# %%
# custom dataset for test set
class BirdTestDataset(Dataset):
    def __init__(self, csv_file, img_dir, transform=None):
        self.df = pd.read_csv(csv_file)
        self.img_dir = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        file_path = self.df.loc[idx, "FILE"]
        full_path = os.path.join(self.img_dir, file_path)
        image = Image.open(full_path).convert("RGB")
        if self.transform:
            image = self.transform(image)
        return image, file_path

# %%
#inference on test set
test_transform = transforms.Compose([
    transforms.Resize((img_size, img_size)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

test_dataset = BirdTestDataset(
    csv_file="/content/dataset/test.csv",
    img_dir="/content/dataset/test",
    transform=test_transform
)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=2)

# Load saved model
model.load_state_dict(torch.load(model_path))
model.eval()

all_preds = []
all_files = []

with torch.no_grad():
    for images, filepaths in test_loader:
        images = images.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_files.extend(filepaths)
# Out:
# <ipython-input-74-9517e6a79c51>:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))

# %%
#convert class id to label
train_df = pd.read_csv("/content/dataset/train.csv")
class_names = train_df.groupby("class id")["labels"].first().to_dict()

#check
print("Class mapping:", class_names)
# Out:
# Class mapping: {0.0: 'ABBOTTS BABBLER', 1.0: 'ABBOTTS BOOBY', 2.0: 'ABYSSINIAN GROUND HORNBILL', 3.0: 'AFRICAN CROWNED CRANE', 4.0: 'AFRICAN EMERALD CUCKOO', 5.0: 'AFRICAN FIREFINCH', 6.0: 'AFRICAN OYSTER CATCHER', 7.0: 'AFRICAN PIED HORNBILL', 8.0: 'AFRICAN PYGMY GOOSE', 9.0: 'ALBATROSS', 10.0: 'ALBERTS TOWHEE', 11.0: 'ALEXANDRINE PARAKEET', 12.0: 'ALPINE CHOUGH', 13.0: 'ALTAMIRA YELLOWTHROAT', 14.0: 'AMERICAN AVOCET', 15.0: 'AMERICAN BITTERN', 16.0: 'AMERICAN COOT', 17.0: 'AMERICAN FLAMINGO', 18.0: 'AMERICAN GOLDFINCH', 19.0: 'AMERICAN KESTREL', 20.0: 'AMERICAN PIPIT', 21.0: 'AMERICAN REDSTART', 22.0: 'AMERICAN ROBIN', 23.0: 'AMERICAN WIGEON', 24.0: 'AMETHYST WOODSTAR', 25.0: 'ANDEAN GOOSE', 26.0: 'ANDEAN LAPWING', 27.0: 'ANDEAN SISKIN', 28.0: 'ANHINGA', 29.0: 'ANIANIAU', 30.0: 'ANNAS HUMMINGBIRD', 31.0: 'ANTBIRD', 32.0: 'ANTILLEAN EUPHONIA', 33.0: 'APAPANE', 34.0: 'APOSTLEBIRD', 35.0: 'ARARIPE MANAKIN', 36.0: 'ASHY STORM PETREL', 37.0: 'ASHY THRUSHBIRD', 38.0: 'ASIAN CRESTED IBIS', 39.0: 'ASIAN DOLLARD BIRD', 40.0: 'ASIAN GREEN BEE EATER', 41.0: 'ASIAN OPENBILL STORK', 42.0: 'AUCKLAND SHAQ', 43.0: 'AUSTRAL CANASTERO', 44.0: 'AUSTRALASIAN FIGBIRD', 45.0: 'AVADAVAT', 46.0: 'AZARAS SPINETAIL', 47.0: 'AZURE BREASTED PITTA', 48.0: 'AZURE JAY', 49.0: 'AZURE TANAGER', 50.0: 'AZURE TIT', 51.0: 'BAIKAL TEAL', 52.0: 'BALD EAGLE', 53.0: 'BALD IBIS', 54.0: 'BALI STARLING', 55.0: 'BALTIMORE ORIOLE', 56.0: 'BANANAQUIT', 57.0: 'BAND TAILED GUAN', 58.0: 'BANDED BROADBILL', 59.0: 'BANDED PITA', 60.0: 'BANDED STILT', 61.0: 'BAR-TAILED GODWIT', 62.0: 'BARN OWL', 63.0: 'BARN SWALLOW', 64.0: 'BARRED PUFFBIRD', 65.0: 'BARROWS GOLDENEYE', 66.0: 'BAY-BREASTED WARBLER', 67.0: 'BEARDED BARBET', 68.0: 'BEARDED BELLBIRD', 69.0: 'BEARDED REEDLING', 70.0: 'BELTED KINGFISHER', 71.0: 'BIRD OF PARADISE', 72.0: 'BLACK AND YELLOW BROADBILL', 73.0: 'BLACK BAZA', 74.0: 'BLACK COCKATO', 75.0: 'BLACK FACED SPOONBILL', 76.0: 'BLACK FRANCOLIN', 77.0: 'BLACK HEADED CAIQUE', 78.0: 'BLACK NECKED STILT', 79.0: 'BLACK SKIMMER', 80.0: 'BLACK SWAN', 81.0: 'BLACK TAIL CRAKE', 82.0: 'BLACK THROATED BUSHTIT', 83.0: 'BLACK THROATED HUET', 84.0: 'BLACK THROATED WARBLER', 85.0: 'BLACK VENTED SHEARWATER', 86.0: 'BLACK VULTURE', 87.0: 'BLACK-CAPPED CHICKADEE', 88.0: 'BLACK-NECKED GREBE', 89.0: 'BLACK-THROATED SPARROW', 90.0: 'BLACKBURNIAM WARBLER', 91.0: 'BLONDE CRESTED WOODPECKER', 92.0: 'BLOOD PHEASANT', 93.0: 'BLUE COAU', 94.0: 'BLUE DACNIS', 95.0: 'BLUE GRAY GNATCATCHER', 96.0: 'BLUE GROSBEAK', 97.0: 'BLUE GROUSE', 98.0: 'BLUE HERON', 99.0: 'BLUE MALKOHA', 100.0: 'BLUE THROATED TOUCANET', 101.0: 'BOBOLINK', 102.0: 'BORNEAN BRISTLEHEAD', 103.0: 'BORNEAN LEAFBIRD', 104.0: 'BORNEAN PHEASANT', 105.0: 'BRANDT CORMARANT', 106.0: 'BREWERS BLACKBIRD', 107.0: 'BROWN CREPPER', 108.0: 'BROWN HEADED COWBIRD', 109.0: 'BROWN NOODY', 110.0: 'BROWN THRASHER', 111.0: 'BUFFLEHEAD', 112.0: 'BULWERS PHEASANT', 113.0: 'BURCHELLS COURSER', 114.0: 'BUSH TURKEY', 115.0: 'CAATINGA CACHOLOTE', 116.0: 'CABOTS TRAGOPAN', 117.0: 'CACTUS WREN', 118.0: 'CALIFORNIA CONDOR', 119.0: 'CALIFORNIA GULL', 120.0: 'CALIFORNIA QUAIL', 121.0: 'CAMPO FLICKER', 122.0: 'CANARY', 123.0: 'CANVASBACK', 124.0: 'CAPE GLOSSY STARLING', 125.0: 'CAPE LONGCLAW', 126.0: 'CAPE MAY WARBLER', 127.0: 'CAPE ROCK THRUSH', 128.0: 'CAPPED HERON', 129.0: 'CAPUCHINBIRD', 130.0: 'CARMINE BEE-EATER', 131.0: 'CASPIAN TERN', 132.0: 'CASSOWARY', 133.0: 'CEDAR WAXWING', 134.0: 'CERULEAN WARBLER', 135.0: 'CHARA DE COLLAR', 136.0: 'CHATTERING LORY', 137.0: 'CHESTNET BELLIED EUPHONIA', 138.0: 'CHESTNUT WINGED CUCKOO', 139.0: 'CHINESE BAMBOO PARTRIDGE', 140.0: 'CHINESE POND HERON', 141.0: 'CHIPPING SPARROW', 142.0: 'CHUCAO TAPACULO', 143.0: 'CHUKAR PARTRIDGE', 144.0: 'CINNAMON ATTILA', 145.0: 'CINNAMON FLYCATCHER', 146.0: 'CINNAMON TEAL', 147.0: 'CLARKS GREBE', 148.0: 'CLARKS NUTCRACKER', 149.0: 'COCK OF THE  ROCK', 150.0: 'COCKATOO', 151.0: 'COLLARED ARACARI', 152.0: 'COLLARED CRESCENTCHEST', 153.0: 'COMMON FIRECREST', 154.0: 'COMMON GRACKLE', 155 ...

# %%
#prediction
num_images = 10
fig, axes = plt.subplots(2, 5, figsize=(15, 6))

model.eval()
with torch.no_grad():
    for i in range(num_images):

        image_path = os.path.join("/content/dataset/test", test_dataset.df.loc[i, "FILE"])
        image = Image.open(image_path).convert("RGB")


        input_tensor = test_transform(image).unsqueeze(0).to(device)


        output = model(input_tensor)
        _, pred = torch.max(output, 1)

        predicted_class = class_names.get(pred.item(), f"Class {pred.item()}")

        ax = axes[i // 5, i % 5]
        ax.imshow(image)
        ax.set_title(f"Pred: {predicted_class}", fontsize=12)
        ax.axis("off")

plt.tight_layout()
plt.show()

# %%
# create file for submission
submission = pd.DataFrame({
    "filepath": all_files,
    "predicted_class_id": all_preds
})
submission.to_csv("/content/dataset/submission.csv", index=False)
print("File submission.csv đã được tạo!")
# Out:
# File submission.csv đã được tạo!

# %%
from google.colab import files
files.download("/content/dataset/submission.csv")
